# %%
import pandas as pd

df = pd.read_csv("player_data_super_league.csv")

# %% [markdown]
# ![WhatsApp Görsel 2024-08-06 saat 22.42.26_c908ac73.jpg](<attachment:WhatsApp Görsel 2024-08-06 saat 22.42.26_c908ac73.jpg>)

# %%
display(df)
# Out:
#                   Player   Nation      Pos   Age  MP  Starts      Min  \
# 0       Fernando Muslera      URU       GK  37.0  45      45   4019.0
# 1         Lucas Torreira      URU       MF  27.0  43      43   3639.0
# 2           Mauro Icardi      ARG       FW  30.0  42      39   3553.0
# 3       Kerem Aktürkoğlu      TUR    MF,FW  24.0  45      36   3052.0
# 4    Abdülkerim Bardakcı      TUR       DF  28.0  35      32   2879.0
# ..                   ...      ...      ...   ...  ..     ...      ...
# 825    Enver Sarıalioğlu  Unknown       MF  19.0   0       0  Unknown
# 826       Jetmir Topalli      KVX       MF  25.0   0       0  Unknown
# 827          Oktay Yakup  Unknown  Unknown  17.0   0       0  Unknown
# 828          Squad Total  Unknown  Unknown  26.4  38     418   3420.0
# 829       Opponent Total  Unknown  Unknown  28.1  38     418   3420.0
#
#          90s      Gls      Ast  ...    PKatt     CrdY     CrdR Gls_per_90  \
# ...
